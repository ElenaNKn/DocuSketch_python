# %%
# import class from created module
from my_plot import Plots

# %%
# define an object of created class
a = Plots()
# Out:
# [2023-05-07 23:49:06,338: INFO] Logging started

# %%
# call a class function
a.draw_plots('deviation.json')
# Out:
# [2023-05-07 23:49:07,605: INFO] Reading file...
# [2023-05-07 23:49:07,617: INFO] Plotting pairplots...
# [2023-05-07 23:49:13,289: INFO] Plotting plot for min and max values...
# {'pairplot': 'D:\\python_works\\test_tasks\\DocuSketch_python\\plots\\pairplot20230507_234910.png',
#  'min-max-plot': 'D:\\python_works\\test_tasks\\DocuSketch_python\\plots\\minmaxplot20230507_234913.png'}

# %%
# try to plot data from unexisted jsonfile
a.draw_plots('deviation_unexisted.json')
# Out:
# [2023-05-07 23:49:14,638: INFO] Reading file...
# [2023-05-07 23:49:14,639: ERROR] File not found!
